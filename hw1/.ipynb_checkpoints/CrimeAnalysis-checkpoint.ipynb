# %% [markdown]
# # HW 1 - Diagnostic - Crime Trends in Chicago
# #### Cecile Murray
#
# ## Problem 1: Data acquisition and preparation

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import censusdata as census
import fiona.crs
from shapely.geometry import Point    
import datetime

# %%
def read_crime_data(*years):
    # bring in crime data for specified years, return geodataframe
    
    crimes = []
    for y in years:
        crimes.append(pd.read_csv('raw/Crimes-{}.csv'.format(y)))
        
    crimes = pd.concat(crimes)
    
    crimes['Date'] = pd.to_datetime(crimes['Date'])
    crimes['Week'] = crimes.Date.dt.week
    crimes['Month'] = crimes.Date.dt.month
    crimes['Year'] = crimes.Date.dt.year

    crimes['coords'] = list(zip(crimes.Longitude, crimes.Latitude))
    crimes['coords'] = crimes['coords'].apply(Point)
    
    return gpd.GeoDataFrame(crimes, geometry = 'coords', crs = fiona.crs.from_epsg(4269))


def join_to_blkgrp(df):
    # merge data frame with Cook County block group shapefile
    
    cook_blks = gpd.read_file('geo/Cook_bg.geojson')
    return gpd.sjoin(df, cook_blks, op = "within", how = 'inner')


def create_comm_area_xwalk():
    # read in community area shapefile and create geographic crosswalk
    
    comm_areas = gpd.read_file('geo/CHI_comm_areas.geojson')
    comm_areas.area_num_1 = comm_areas.area_num_1.astype(float)
    comm_areas.rename(columns = {'community':'Neighborhood'}, inplace=True)
    comm_xwalk = comm_areas[['Neighborhood', 'area_num_1']]

    return comm_areas, comm_xwalk

geocrimes = read_crime_data(2017, 2018)
geocrimes = join_to_blkgrp(geocrimes)
comm_areas, comm_xwalk = create_comm_area_xwalk()

# %% [markdown]
# ## Problem 1: Summary Statistics
#
# ### Common types of crime
#
# The table below shows that theft, battery, and criminal damage were the most common forms of crime. While the number of thefts, batteries, and assaults increased between 2017 and 2018, the number of criminal damage incidents and deceptive practice offenses declined somewhat. There were substantial declines in robberies, motor vehicle thefts, and homicides, but notable increases in narcotics offenses and weapons violations.

# %%
def compute_crime_change(df):

    df = df[['Year','Primary Type', 'ID']].groupby(['Year', 'Primary Type']).count().unstack(0)['ID']
    df['Percent Change'] = ((df[2018] - df[2017]) / df[2017]) * 100
    return df.sort_values(by = 2018, ascending=False)

type_summary = compute_crime_change(geocrimes)
type_summary
# Out:
# Year                                2017   2018  Percent Change
# Primary Type
# THEFT                              63583  64023        0.692009
# BATTERY                            49135  49719        1.188562
# CRIMINAL DAMAGE                    28950  27700       -4.317789
# ASSAULT                            19250  20341        5.667532
# DECEPTIVE PRACTICE                 17768  17863        0.534669
# OTHER OFFENSE                      16965  16970        0.029472
# NARCOTICS                          11474  12798       11.539132
# BURGLARY                           12947  11687       -9.731984
# MOTOR VEHICLE THEFT                11367   9963      -12.351544
# ROBBERY                            11868   9680      -18.436131
# CRIMINAL TRESPASS                   6799   6881        1.206060
# WEAPONS VIOLATION                   4682   5444       16.275096
# OFFENSE INVOLVING CHILDREN          2145   2176        1.445221
# CRIM SEXUAL ASSAULT                 1541   1589        3.114860
# PUBLIC PEACE VIOLATION              1493   1361       -8.841259
# INTERFERENCE WITH PUBLIC OFFICER    1083   1305       20.498615
# SEX OFFENSE                          939   1061       12.992545
# PROSTITUTION                         734    717       -2.316076
# HOMICIDE                             676    586      -13.313609
# ARSON                                444    372      -16.216216
# LIQUOR LAW VIOLATION                 191    265       38.743455
# GAMBLING                             191    201        5.235602
# STALKING                             184    201        9.239130
# KIDNAPPING                           190    169      -11.052632
# INTIMIDATION                         150    166       10.666667
# CONCEALED CARRY LICENSE VIOLATION     69    148      114.492754
# OBSCENITY                             80     86        7.500000
# NON-CRIMINAL                          37     37        0.000000
# PUBLIC INDECENCY                      10     14       40.000000
# HUMAN TRAFFICKING                      8     14       75.000000
# NON-CRIMINAL (SUBJECT SPECIFIED)       2      3       50.000000
# OTHER NARCOTIC VIOLATION              11      1      -90.909091

# %% [markdown]
# ### The most crimes occurred near the Loop and in West Side neighborhoods
#
# The Austin neighborhood experienced the largest number of crimes in 2017 and 2018, followed by River North and the Loop. Several other West Side neighborhoods make the list of the ten neighborhoods with the most crime during this period, as well as two South Side neighborhoods. Meanwhile, as shown in the map below, the neighborhoods that experienced the smallest number of crimes were largely smaller and farther away from the center of the city.

# %%
nhood_summary = geocrimes[['Community Area', 'ID']].groupby(['Community Area']).count().reset_index()
nhood_summary.rename(columns = {'ID':'Crimes', 'Community Area':'area_num_1'}, inplace = True)
nhood_summary = pd.merge(comm_areas, nhood_summary, on='area_num_1').sort_values(by='Crimes', ascending=False)
nhood_summary[['Neighborhood', 'Crimes']].iloc[0:9]
# Out:
#        Neighborhood  Crimes
# 25           AUSTIN   30220
# 36  NEAR NORTH SIDE   24960
# 37             LOOP   21140
# 29   NORTH LAWNDALE   18210
# 28   NEAR WEST SIDE   18203
# 38      SOUTH SHORE   17176
# 23    HUMBOLDT PARK   15989
# 24        WEST TOWN   15389
# 69   AUBURN GRESHAM   14775

# %%
nhood_summary.plot(column='Crimes')

# %% [markdown]
# ### Arrest rates vary widely across different types of crime

# %%
arrests = geocrimes[['Primary Type', 'Arrest', 'ID']].groupby(['Primary Type', 'Arrest']).count().sort_values(by='Primary Type', ascending=False).reset_index()
arrests = arrests.pivot(index='Primary Type', columns='Arrest', values='ID').reset_index()
arrests.columns = ['Primary Type', 'NoArrest', 'Arrest']
arrests['Arrest Rate'] = arrests['Arrest'] / (arrests['Arrest'] + arrests['NoArrest'])
arrests = arrests[['Primary Type', 'Arrest Rate']].sort_values(by='Arrest Rate').loc[arrests['Arrest Rate'] > 0]
arrests_plot = arrests.set_index('Primary Type').plot(kind = 'barh', figsize = (12, 10), title = 'Arrest rates vary across offenses')

# %% [markdown]
# ### Crime increases in the spring and summer

# %%
# summarize by month, and plot
crime_by_month = geocrimes.groupby(['Month'])['Primary Type'].count()
seasonal_plot = crime_by_month.plot(figsize = (7,5), title = 'Crime trends vary seasonally')

# %% [markdown]
# ## Problem 2: Demographic analysis
#
# This section describes the demographic characteristics of blocks where certain kinds of crimes commonly occurred. I assemble data from the most recent five-year American Community Survey on Census block groups in Cook County. In particular, I look at the following variables:
#
# * Median household income
# * Racial composition: the share of the population that is white non-Hispanic, African-American (not Hispanic), and Hispanic
# * Share of single-parent households
# * Share of households composed of individuals living alone
# * Share of the adult population with less than a high school diploma
# * Share of the adult population with a college degree

# %%
# set some global variables to make indexing less error-prone
TRACTCODE = 2
BLKGRPCODE = 3
HSBEGIN = 2
HSEND = 17
BABEGIN = 22
EDUEND = 26

# construct lists of variables for the API query
def make_api_varlist(table_id, var_start, var_stop):
    ''' Takes a table id string and start/stop indices for variable selection
        Returns: list of variables for census API call'''
    
    return list(map(lambda x: table_id + '_' + str(x).zfill(3) + 'E', range(var_start, var_stop)))
    
hhold_vars = make_api_varlist('B11001', 1, 10)
race_vars = make_api_varlist('B03002', 1, 21)
edu_vars = make_api_varlist('B15003', 1, 26)

# make the query for all block groups in Cook County, in two chunks because the API only takes 50 variables at a time
data = census.download('acs5', 2017,
    census.censusgeo([('state', '17'), ('county', '031'), ('block group', '*')]),
    hhold_vars + race_vars).reset_index()
edu = census.download('acs5', 2017,
    census.censusgeo([('state', '17'), ('county', '031'), ('block group', '*')]),
    edu_vars + ['B19013_001E']).reset_index()
edu['pct_nohs'] = edu.iloc[:,HSBEGIN:HSEND].sum(axis=1) / edu['B15003_001E']
edu['pct_BA'] = edu.iloc[:,BABEGIN:EDUEND].sum(axis=1) / edu['B15003_001E']

data = pd.merge(data, edu, on='index')

# create unique FIPS ID
data['GEOID'] = data['index'].apply(lambda x: '17031' + x.geo[TRACTCODE][1] + x.geo[BLKGRPCODE][1])

# compute variables of interest
data['pct_1parent'] = data['B11001_004E'] / data['B11001_001E']
data['pct_alone'] = data['B11001_008E'] / data['B11001_001E']
data['pct_white'] = data['B03002_003E'] / data['B03002_001E']
data['pct_black'] = data['B03002_004E'] / data['B03002_001E']
data['pct_hisp'] = data['B03002_012E'] / data['B03002_001E']
data['medinc'] = data['B19013_001E'].replace(-666666666, np.nan)
vars = ['pct_1parent', 'pct_alone', 'pct_white', 'pct_black', 'pct_hisp', 'pct_nohs', 'pct_BA', 'medinc']

# finally, select only variables of interest and merge with crimes geodataframe
acs = data[['GEOID'] + vars]
geocrimes = geocrimes.merge(acs, on = 'GEOID')

# %% [markdown]
# ### Battery vs. homicide
#
# Homicides occurred more often in areas that appear more economically disadvantaged, that have higher shares of single-parent households, and have higher shares of African-American residents. The percentage of Hispanic residents and the percentage of individuals living alone is not markedly different for blocks where homicides occured compared with those where none occurred.
# * The average median income of block groups that experienced a homicide in 2017 or 2018 was \\$35,605, compared with \\$52,107 in block groups that did not experience a homicide in this time frame.
# * Additionally, homicides tended to occur in areas with lower educational attainment: the share of adult residents with a college degree in block groups where homicides had occurred was half of what it was in those block groups where no homicide occurred. The share of adult residents who did not finish high school was slightly higher in the former areas as well.
# * The share of single-parent-headed households is about a third higher in block groups where homicides occurred.
#
# Similar patterns are evident among blocks where battery was reported in 2017 or 2018, but they are less stark. There are still noticeably lower median incomes and rates of college degree attainment and higher rates of single parenthood in block groups where battery occurred, as well as a continued racial gap.

# %%
def create_var_dict():
    '''Creates mapping between convenient variable abbreviations and human-readable names'''
    
    vars = ['pct_1parent', 'pct_alone', 'pct_white', 'pct_black', 'pct_hisp','pct_nohs', 'pct_BA', 'medinc']
    varlabels = ['% Single parent households', '% Living Alone', '% Non-Hispanic White', '% African-American',
             '% Hispanic', '% Adults without high school diploma', '% Adults with a college degree',
                 'Median Household Income']
    return dict(zip(vars, varlabels))


def compare_crime_types(df, crime1, crime2, vars):
    '''Compare mean characteristics of blocks where two crimes occurred'''
 
    out = pd.concat([df.loc[df['Primary Type'] == crime1.upper(), vars].mean(),
                     df.loc[df['Primary Type'] == crime2.upper(), vars].mean()],
                     keys = [crime1, crime2], names = [crime1.title(), crime2.title()])
        
    return pd.DataFrame(out).unstack().rename(columns = var_dict)
    

var_dict = create_var_dict()
compare_crime_types(geocrimes, 'homicide', 'battery', vars)[0]
# Out:
# Battery   % Single parent households  % Living Alone  % Non-Hispanic White  \
# Homicide
# homicide                    0.393009        0.327541              0.072745
# battery                     0.326786        0.347406              0.172836
#
# Battery   % African-American  % Hispanic  \
# Homicide
# homicide            0.719211    0.178276
# battery             0.575798    0.198264
#
# Battery   % Adults without high school diploma  \
# Homicide
# homicide                              0.216163
# battery                               0.190280
#
# Battery   % Adults with a college degree  Median Household Income
# Homicide
# homicide                        0.165893             35605.407973
# battery                         0.253772             44427.108709

# %%
# do a year by year comparison
pd.concat([compare_crime_types(geocrimes.loc[(geocrimes['Year'] == 2017)], 'homicide', 'battery', vars)[0],
           compare_crime_types(geocrimes.loc[(geocrimes['Year'] == 2018)], 'homicide', 'battery', vars)[0]],
         keys = ['2017', '2018'])
# Out:
# Battery        % Single parent households  % Living Alone  \
#      Homicide
# 2017 homicide                    0.390737        0.323730
#      battery                     0.328773        0.346021
# 2018 homicide                    0.395631        0.331938
#      battery                     0.324822        0.348774
#
# Battery        % Non-Hispanic White  % African-American  % Hispanic  \
#      Homicide
# 2017 homicide              0.068091            0.708510    0.196045
#      battery               0.169792            0.580227    0.198131
# 2018 homicide              0.078116            0.731559    0.157772
#      battery               0.175844            0.571420    0.198395
#
# Battery        % Adults without high school diploma  \
#      Homicide
# 2017 homicide                              0.217205
#      battery                               0.191031
# 2018 homicide                              0.214961
#      battery                               0.189538
#
# Battery        % Adults with a college degree  Median Household Income
#      Homicide
# 2017 homicide                        0.163568             36113.160063
#      battery                         0.250411             44098.278474
# 2018 homicide                        0.168577             35020.751825
#      battery                         0.257093             44753.060613

# %% [markdown]
# ### Deceptive practices vs. sex offenses
#
# Block groups were deceptive practices offenses occurred had higher college degree attainment rates, higher shares of non-Hispanic white people, and higher median incomes relative to blocks where sex offenses occured. Block groups where sex offenses occurred had somewhat higher shares of single parent households and larger minority populations.

# %%
compare_crime_types(geocrimes, 'sex offense', 'deceptive practice', vars)[0]
# Out:
# Deceptive Practice  % Single parent households  % Living Alone  \
# Sex Offense
# sex offense                           0.263620        0.351911
# deceptive practice                    0.206924        0.395604
#
# Deceptive Practice  % Non-Hispanic White  % African-American  % Hispanic  \
# Sex Offense
# sex offense                     0.275173            0.398523    0.253196
# deceptive practice              0.375672            0.346372    0.181772
#
# Deceptive Practice  % Adults without high school diploma  \
# Sex Offense
# sex offense                                     0.181953
# deceptive practice                              0.127303
#
# Deceptive Practice  % Adults with a college degree  Median Household Income
# Sex Offense
# sex offense                               0.329846             53131.910479
# deceptive practice                        0.452756             66326.748194

# %% [markdown]
# ## Problem 3: Analysis and communication
#
# The overall number of crimes decreased slightly in Chicago between 2017 and 2018, but this decrease masks wide variation by crime type. Several types of violent crime, including homicide and robbery, fell over this period, but there was significant growth in potentially dangerous crimes such as weapons violations and assaults.

# %%
pd.DataFrame(geocrimes.groupby('Year').count().rename(columns = {'ID':'Number of Crimes'}).iloc[:,0])
# Out:
#       Number of Crimes
# Year
# 2017            264966
# 2018            263541

# %%
# Plot percent change in crime by type for crimes that occurred with some frequency
type_summary = type_summary.loc[type_summary[2017] > 100].sort_values(by = 'Percent Change')['Percent Change']
plot1 = type_summary.plot(kind = 'barh', title = "Percent Change in Crime by Type, 2017-2018", figsize=(12, 10))

# %% [markdown]
# ### Fact-checking an alderman candidate
#
# Alderman candidate Jacob Ringer's claims about increases in specific types of crime between a specified month in 2017 and 2018 do not appear to be correct. Below, I analyze data for the four weeks leading up to July 26 in 2017 and 2018 and compute the percent change in each crime in his ward between the two years. I find that compared with the same four weeks in 2017, robberies declined by about 12 percent, batteries increased by only 4 percent, burglaries decreased by 8 percent, and motor vehicle thefts decreased by 15 percent.
#
# Even if these statistics were correct, I showed above that crime has a clear seasonal trend, so even if crime trends were the same from year to year, one would expect to see an increase in crime over the month he mentions purely due to seasonal factors.

# %%
def extract_month(df, crime, year, month, day):
    '''Computes number of given crimes in the four weeks prior to a given time frame'''
    
    date = datetime.date(year, month, day)
    week = date.isocalendar()[1]
    
    df = df.loc[df.Year == year]
    period = df.loc[(df['Week'] > week - 4) & (df['Week'] <= week) & (df['Primary Type'] == crime.upper())]
    
    return period.count().ID

def compare_crimes(df, *crimes):
    
    out = []
    for c in crimes:
        c1 = extract_month(geocrimes, c, 2017, 7, 26)
        c2 = extract_month(geocrimes, c, 2018, 7, 26)
        out.append((c2 - c1) / c1)
    
    return out

compare_crimes(geocrimes.loc[geocrimes['Ward'] == 43],
               'robbery', 'battery', 'burglary', 'motor vehicle theft')
# Out:
# [-0.11602209944751381,
#  0.041971233199717045,
#  -0.07811080835603997,
#  -0.152317880794702]

# %% [markdown]
# ### Key findings about crime in Chicago
#
#
# An analysis of crime data from the City of Chicago's open data portal reveals a few key facts about crime trends in Chicago:
#
# * **The most common types of crime are theft, battery, and criminal damage.** As a result, targeting policing resources to reducing these three types of crime by even a modest amount could result in a substantial decline in the overall number of crimes.
#
# * **The neighborhoods with the most crime are located near the Loop or on the city's west side.** The Austin neighborhood experienced the largest number of crimes in 2017 and 2018, followed by River North and the Loop. Several other West Side neighborhoods make the list of the ten neighborhoods with the most crime during this period, as well as a couple of South Side neighborhoods. The neighborhoods that experienced the smallest number of crimes were largely smaller and farther away from the center of the city. Developing and implementing strategies to improve the efficacy of policing in these areas could help improve public safety in these areas. In addition, the city may wish to target other social and economic resources to residents of these communities to help counteract the effects of living in a higher-crime neighborhood.
#
# * **Arrest rates vary widely by crime type.** Nearly all narcotics offenses, concealed carry license violations, and interference with public officer incidents resulted in arrests, while arrests rates were near or below 25 percent for more violent crimes like homicide, assault, battery, and sex offenses. In part, this pattern is likely because some crimes are only recorded when an arrest occurs; for example, the police can only be aware of a concealed carry license violation if they stop and individual and check them for a concealed weapons. However, the low arrest rates for homicide and other serious violent crimes could still be an indicator that policing strategies around these kinds of crimes should be improved.
#
# * **Crime frequency rises in the spring and summer and falls in the autumn and winter.** Analyzing the number of crimes by month in 2017 and 2018 shows that more crimes happen in warmer months than they do in colder months. The City could invest more heavily in summer programming to help strengthen community ties and provide alternatives to criminal activity during these months.
#
# * **Certain crimes disproportionately affect low socioeconomic status neighborhoods.** Homicides and batteries occurred more often in areas that appear more economically disadvantaged and that have higher shares of single-parent households and lower educational attainment. These neighborhoods also have higher shares of African-American residents, potentially indicating racial disparities. The City should further study how these disparities contribute to crime and identify appropriate interventions.

# %% [markdown]
# ### Caveats and limitations

# %% [markdown]
# The above analysis has several important limitations.
#
# * Since crimes are only recorded when they are reported, it is likely that these data miss a substantial number of crimes. These missing crimes are probably not missing at random. For example, homicides are probably very likely to be reported, whereas sex offenses may not be if victims fear stigma. Additionally, reporting rates for different neighnorhoods likely vary based on how much residents trust the police and how heavily police are deployed to different areas.
#
# * Additionally, this analysis does not control for the degree to which areas are heavily trafficked. One might expect more crimes where more people are interacting.
#
# * The correlations between socioeconomic and demographic factors and crime should be interpreted as descriptive rather than causal. This analysis alone does not demonstrate a causal link between educational attainment and lower crime, for example, merely an association at the average.

# %% [markdown]
# ## Problem 4: 911 call probabilities
#
# A. Based on past data about reported crimes in the 2100 block of S. Michigan Avenue, a call comes in from that block is most likely to be battery, since this type of crime made up 16 of the 59 total crimes reported there in 2017 and 2018.

# %%
smich_total = geocrimes['Block'].loc[geocrimes.Block == '021XX S MICHIGAN AVE'].count()
smich = geocrimes[['Block', 'Primary Type']].loc[geocrimes.Block == '021XX S MICHIGAN AVE'].groupby(['Primary Type']).count().sort_values(by='Block', ascending=False)
smich['Probability'] = smich.Block / 59
smich
# Out:
#                         Block  Probability
# Primary Type
# BATTERY                    16     0.271186
# OTHER OFFENSE              12     0.203390
# ASSAULT                     6     0.101695
# CRIMINAL DAMAGE             6     0.101695
# DECEPTIVE PRACTICE          6     0.101695
# THEFT                       6     0.101695
# MOTOR VEHICLE THEFT         2     0.033898
# ROBBERY                     2     0.033898
# BURGLARY                    1     0.016949
# CRIMINAL TRESPASS           1     0.016949
# PUBLIC PEACE VIOLATION      1     0.016949

# %% [markdown]
# B. If a call comes in about theft, it is more likely to come from Garfield Park. Assuming that Garfield Park is the combination of West Garfield Park and East Garfield Park, there were 2,475 thefts reported in Garfield Park compared with 1,919 thefts reported in Uptown. In total, there were 127,606 reported thefts, so the probability that a call about theft comes from Uptown is 1.5 percent and the probability that such a call comes from Garfield Park is about 1.9 percent. Put differently, that means that a call about theft is about 29 percent more likely to have come from Garfield Park than from Uptown.

# %%
theft = geocrimes.loc[geocrimes['Primary Type'] == 'THEFT']
theft_total = theft.count().ID

# %%
theft = geocrimes.loc[geocrimes['Primary Type'] == 'THEFT']
theft = theft[['Community Area', 'Primary Type']].groupby('Community Area').count().reset_index()
theft['Total'] = theft_total
theft = theft.rename(columns = {'Community Area':'area_num_1', 'Primary Type':'Thefts'}).merge(comm_xwalk, on='area_num_1')
theft['Percent of total'] = theft['Thefts'] / theft['Total']
theft.sort_values(by='Thefts', ascending=False)
theft.loc[(theft['Neighborhood'] == 'UPTOWN') |
          (theft['Neighborhood'] == 'EAST GARFIELD PARK') | 
          (theft['Neighborhood'] == 'WEST GARFIELD PARK')]
# Out:
#     area_num_1  Thefts   Total        Neighborhood  Percent of total
# 2          3.0    1919  127606              UPTOWN          0.015038
# 25        26.0    1208  127606  WEST GARFIELD PARK          0.009467
# 26        27.0    1267  127606  EAST GARFIELD PARK          0.009929

# %% [markdown]
# C. Given the data provided, there are 260 total calls about battery, of which 160 come from Uptown and 100 come from Garfield Park. Consequently, based on past calls, the probability that a call about battery comes from Uptown is about 0.62, whereas the probability that the call comes from Garfield Park is about 0.38. Put differently, the call is about 23% more likely to have come from Uptown than from Garfield Park.
