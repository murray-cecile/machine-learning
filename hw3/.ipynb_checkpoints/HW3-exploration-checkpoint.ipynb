# %% [markdown]
# The problem is to predict if a project on donorschoose will not get fully funded within 60 days of posting.
# * This prediction is being done at the time of posting so you can only use data available to you at that time.
# * The data is a file that has one row for each project posted with a column for "date_posted" (the date the project was posted) and a column for "datefullyfunded" (the date the project was fully funded - assumption for this assignment is that all projects were fully funded eventually).
# * The data spans Jan 1, 2012 to Dec 31, 2013.
# * You should have your validation/test set be a rolling window of 6 months (which should give you three test sets).
# * The training sets should be everything from 1/1/12 to the beginning of the test set.

# %%
# basic dependencies
import datetime
import numpy as np
import pandas as pd 
import seaborn as sns
import plotnine as p9
import matplotlib.pyplot as plt
from sklearn import preprocessing

# my own library of useful functions
import utils
import exploration as exp
import pipeline as pipe

# %%
projraw = utils.read_data('projects_2012_2013', 'csv')

# %%
projraw.head()
# Out:
#                           projectid                    teacher_acctid  \
# 0  00001ccc0e81598c4bd86bacb94d7acb  96963218e74e10c3764a5cfb153e6fea
# 1  0000fa3aa8f6649abab23615b546016d  2a578595fe351e7fce057e048c409b18
# 2  000134f07d4b30140d63262c871748ff  26bd60377bdbffb53a644a16c5308e82
# 3  0001f2d0b3827bba67cdbeaa248b832d  15d900805d9d716c051c671827109f45
# 4  0004536db996ba697ca72c9e058bfe69  400f8b82bb0143f6a40b217a517fe311
#
#                            schoolid  school_ncesid  school_latitude  \
# 0  9f3f9f2c2da7edda5648ccd10554ed8c   1.709930e+11        41.807654
# 1  3432ed3d4466fac2f2ead83ab354e333   6.409801e+10        34.296596
# 2  dc8dcb501c3b2bb0b10e9c6ee2cd8afd   6.227100e+10        34.078625
# 3  8bea7e8c6e4279fca6276128db89292e   3.600090e+11        40.687286
# 4  fbdefab6fe41e12c55886c610c110753   3.606870e+11        40.793018
#
#    school_longitude    school_city school_state school_metro  \
# 0        -87.673257        Chicago           IL        urban
# 1       -119.296596        Ventura           CA        urban
# 2       -118.257834    Los Angeles           CA        urban
# 3        -73.988217       Brooklyn           NY        urban
# 4        -73.205635  Central Islip           NY     suburban
#
#                 school_district       ...       secondary_focus_subject  \
# 0         Pershing Elem Network       ...                   Visual Arts
# 1  Ventura Unif School District       ...          Literature & Writing
# 2     Los Angeles Unif Sch Dist       ...               Social Sciences
# 3      New York City Dept Of Ed       ...                           NaN
# 4   Central Islip Union Free SD       ...          Literature & Writing
#
#   secondary_focus_area resource_type    poverty_level    grade_level  \
# 0     Music & The Arts      Supplies  highest poverty  Grades PreK-2
# 1  Literacy & Language         Books  highest poverty     Grades 3-5
# 2     History & Civics    Technology     high poverty     Grades 3-5
# 3                  NaN         Books     high poverty  Grades PreK-2
# 4  Literacy & Language    Technology     high poverty  Grades PreK-2
#
#   total_price_including_optional_support students_reached  \
# 0                                1498.61             31.0
# 1                                 282.47             28.0
# 2                                1012.38             56.0
# 3                                 175.33             23.0
# 4                                3591.11            150.0
#
#   eligible_double_your_impact_match date_posted datefullyfunded
# 0                                 f     4/14/13          5/2/13
# 1                                 t      4/7/12         4/18/12
# 2                                 f     1/30/12         4/15/12
# 3                                 f    10/11/12         12/5/12
# 4                                 f      1/8/13         3/25/13
#
# [5 rows x 26 columns]

# %%
utils.find_cols_with_missing(projraw)
# Out:
# school_ncesid               9233
# school_metro               15224
# school_district              172
# primary_focus_subject         15
# primary_focus_area            15
# secondary_focus_subject    40556
# secondary_focus_area       40556
# resource_type                 17
# grade_level                    3
# students_reached              59
# dtype: int64

# %%
projraw.info()
# results of this make me want to not include secondary focus subject or area as a feature.
# Create boolean features for is_subject... etc. Then I can include nans.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124976 entries, 0 to 124975
# Data columns (total 26 columns):
# projectid                                 124976 non-null object
# teacher_acctid                            124976 non-null object
# schoolid                                  124976 non-null object
# school_ncesid                             115743 non-null float64
# school_latitude                           124976 non-null float64
# school_longitude                          124976 non-null float64
# school_city                               124976 non-null object
# school_state                              124976 non-null object
# school_metro                              109752 non-null object
# school_district                           124804 non-null object
# school_county                             124976 non-null object
# school_charter                            124976 non-null object
# school_magnet                             124976 non-null object
# teacher_prefix                            124976 non-null object
# primary_focus_subject                     124961 non-null object
# primary_focus_area                        124961 non-null object
# secondary_focus_subject                   84420 non-null object
# secondary_focus_area                      84420 non-null object
# resource_type                             124959 non-null object
# poverty_level                             124976 non-null object
# grade_level                               124973 non-null object
# total_price_including_optional_support    124976 non-null float64
# students_reached                          124917 non-null float64
# eligible_double_your_impact_match         124976 non-null object
# date_posted                               124976 non-null object
# datefullyfunded                           124976 non-null object
# dtypes: float64(5), object(21)
# memory usage: 24.8+ MB

# %% [markdown]
# Here's what I'm going to do to this dataframe:
# * convert date columns to dates
# * convert t/f columns to actual booleans
# * take the categorical variables and convert them to binary
# * what should I normalize??? probably price, students reached

# %%
# convert categorical variables to binary
categorical_list = ['school_metro',
                    'school_state',
                    'primary_focus_subject',
                    'primary_focus_area',
                    'secondary_focus_subject',
                    'secondary_focus_area', 
                    'resource_type', 
                    'poverty_level',
                    'grade_level']
proj = utils.make_cat_dummy(projraw, categorical_list)

# create major city dummy for biggest cities
big_cities = ['Los Angeles', 'Chicago', 'Houston', 'Brooklyn', 'Bronx', 'New York']
proj['in_big_city'] = np.where(proj['school_city'].isin(big_cities), 1, 0)

# create dummies for female teacher and teacher with doctorate
proj['teacher_is_female'] = np.where(proj['teacher_prefix'].isin(['Mrs.', 'Ms.']), True, False)
proj['teacher_is_dr'] = np.where(proj['teacher_prefix'] == 'Dr.', True, False)

# replace string true/false with boolean values
proj = utils.convert_to_boolean(proj, ['school_charter',
                                       'school_magnet',
                                      'eligible_double_your_impact_match'], 't', 'f')

# replace NAs in students reached
proj['students_reached'] = proj['students_reached'].fillna(0)

# normalize project price and students reached
proj['total_price_norm'] = preprocessing.scale(proj['total_price_including_optional_support'].astype('float64'))
proj['students_reached_norm'] = preprocessing.scale(proj['students_reached'].astype('float64'))

# convert date fields and compute whether project is funded within 60 days
proj['date_posted'] = pd.to_datetime(proj.date_posted) 
proj['datefullyfunded'] = pd.to_datetime(proj.datefullyfunded)
proj['not_funded'] = np.where(proj.datefullyfunded - proj.date_posted > datetime.timedelta(days=60), 1, 0)

# %%
proj.corr()['not_funded'].reset_index().sort_values('not_funded')
# Out:
#                                              index  not_funded
# 7                eligible_double_your_impact_match   -0.099572
# 1                                  school_latitude   -0.063793
# 138                         resource_type_Supplies   -0.061064
# 10                              school_metro_urban   -0.060293
# 136                            resource_type_Books   -0.054274
# 144                  poverty_level_highest poverty   -0.045027
# 46                                 school_state_NY   -0.043490
# 97             primary_focus_area_Music & The Arts   -0.038206
# 72     primary_focus_subject_Environmental Science   -0.034551
# 96               primary_focus_area_Math & Science   -0.030698
# 82                     primary_focus_subject_Music   -0.026688
# 18                                 school_state_CT   -0.025535
# 140                            resource_type_Trips   -0.025359
# 133          secondary_focus_area_Music & The Arts   -0.024018
# 90               primary_focus_subject_Visual Arts   -0.023495
# 26                                 school_state_IL   -0.023257
# 153                                    in_big_city   -0.022244
# 43                                 school_state_NJ   -0.022036
# 19                                 school_state_DC   -0.021500
# 76     primary_focus_subject_Health & Life Science   -0.020903
# 122        secondary_focus_subject_Performing Arts   -0.019095
# 4                                    school_magnet   -0.016915
# 3                                   school_charter   -0.016644
# 23                                 school_state_HI   -0.016406
# 59                                 school_state_WA   -0.016211
# 112  secondary_focus_subject_Health & Life Science   -0.015792
# 64          primary_focus_subject_Applied Sciences   -0.014951
# 27                                 school_state_IN   -0.014693
# 118                  secondary_focus_subject_Music   -0.014062
# 17                                 school_state_CO   -0.013876
# ..                                             ...         ...
# 103  secondary_focus_subject_College & Career Prep    0.013588
# 0                                    school_ncesid    0.013768
# 92             primary_focus_area_Applied Learning    0.014484
# 9                            school_metro_suburban    0.014630
# 55                                 school_state_TX    0.014922
# 22                                 school_state_GA    0.015612
# 84                     primary_focus_subject_Other    0.017272
# 120                  secondary_focus_subject_Other    0.017480
# 36                                 school_state_MO    0.018243
# 30                                 school_state_LA    0.018349
# 39                                 school_state_NC    0.018477
# 131       secondary_focus_area_Literacy & Language    0.018553
# 67     primary_focus_subject_College & Career Prep    0.019132
# 79                  primary_focus_subject_Literacy    0.019422
# 117            secondary_focus_subject_Mathematics    0.019692
# 45                                 school_state_NV    0.021599
# 11                                school_metro_nan    0.022656
# 80      primary_focus_subject_Literature & Writing    0.023454
# 146                 poverty_level_moderate poverty    0.023557
# 21                                 school_state_FL    0.028769
# 143                     poverty_level_high poverty    0.031592
# 52                                 school_state_SC    0.036827
# 95          primary_focus_area_Literacy & Language    0.038285
# 8                               school_metro_rural    0.050992
# 5           total_price_including_optional_support    0.085499
# 156                               total_price_norm    0.085499
# 139                       resource_type_Technology    0.112216
# 158                                     not_funded    1.000000
# 63                                school_state_nan         NaN
# 147                              poverty_level_nan         NaN
#
# [159 rows x 2 columns]

# %%
not_feature_cols = ['teacher_acctid',
                    'schoolid',
                    'school_ncesid',
                    'school_latitude', 
                    'school_longitude',
                    'school_district',
                    'school_county',
                    'school_city',
                    'projectid',
                    'teacher_prefix',
                    'date_posted',
                    'datefullyfunded',
                    'not_funded',
                    'interval',
                    'bins',
                    'students_reached',
                   'total_price_including_optional_support']
features = list(set(proj.columns).difference(not_feature_cols))
features
# Out:
# ['school_state_SC',
#  'school_state_WV',
#  'secondary_focus_area_Special Needs',
#  'school_state_IA',
#  'secondary_focus_subject_Civics & Government',
#  'resource_type_Supplies',
#  'school_state_ME',
#  'school_state_WY',
#  'secondary_focus_subject_Economics',
#  'secondary_focus_area_nan',
#  'school_metro_rural',
#  'secondary_focus_subject_Literature & Writing',
#  'secondary_focus_subject_Health & Life Science',
#  'poverty_level_nan',
#  'secondary_focus_subject_nan',
#  'school_state_TX',
#  'secondary_focus_subject_Mathematics',
#  'primary_focus_area_Literacy & Language',
#  'secondary_focus_subject_ESL',
#  'secondary_focus_subject_Other',
#  'primary_focus_subject_Applied Sciences',
#  'primary_focus_subject_Parent Involvement',
#  'primary_focus_subject_Literature & Writing',
#  'secondary_focus_subject_Applied Sciences',
#  'school_state_MI',
#  'secondary_focus_subject_Gym & Fitness',
#  'primary_focus_subject_Character Education',
#  'primary_focus_subject_Other',
#  'grade_level_Grades 6-8',
#  'teacher_is_dr',
#  'primary_focus_subject_Social Sciences',
#  'primary_focus_subject_Sports',
#  'secondary_focus_area_Math & Science',
#  'school_state_NE',
#  'school_state_CO',
#  'secondary_focus_subject_Visual Arts',
#  'school_state_AZ',
#  'school_state_OR',
#  'secondary_focus_subject_Environmental Science',
#  'school_state_AR',
#  'school_state_CT',
#  'school_state_ND',
#  'poverty_level_moderate poverty',
#  'secondary_focus_subject_Sports',
#  'school_state_NY',
#  'school_state_MD',
#  'secondary_focus_subject_Character Education',
#  'primary_focus_area_Music & The Arts',
#  'primary_focus_subject_Mathematics',
#  'primary_focus_subject_Foreign Languages',
#  'primary_focus_area_Math & Science',
#  'secondary_focus_subject_College & Career Prep',
#  'primary_focus_subject_Special Needs',
#  'school_state_AL',
#  'school_state_OK',
#  'primary_focus_subject_Nutrition',
#  'school_state_DC',
#  'eligible_double_your_impact_match',
#  'secondary_focus_area_Health & Sports',
#  'school_state_NJ',
#  'school_state_MT',
#  'secondary_focus_subject_Music',
#  'primary_focus_subject_Performing Arts',
#  'primary_focus_area_Special Needs',
#  'resource_type_nan',
#  'school_state_ID',
#  'school_state_AK',
#  'school_state_TN',
#  'primary_focus_subject_nan',
#  'school_metro_nan',
#  'school_state_MO',
#  'school_state_IL',
#  'primary_focus_area_Health & Sports',
#  'secondary_focus_subject_Social Sciences',
#  'school_state_WA',
#  'school_state_IN',
#  'school_state_MN',
#  'secondary_focus_subject_Early Development',
#  'secondary_focus_subject_Parent Involvement',
#  'poverty_level_low poverty',
#  'primary_focus_subject_Literacy',
#  'secondary_focus_area_Applied Learning',
#  'school_state_NV',
#  'primary_focus_subject_College & Career Prep',
#  'school_state_VA',
#  'school_state_KS',
#  'primary_focus_subject_ESL',
#  'school_state_VT',
#  'school_state_HI',
#  'school_state_MS',
#  'grade_level_Grades PreK-2',
#  'school_state_NM',
#  'primary_focus_subject_Community Service',
#  'resource_type_Other',
#  'primary_focus_subject_Civics & Government',
#  'resource_type_Visitors',
#  'secondary_focus_subject_Special Needs',
#  'poverty_level_highest poverty',
#  'secondary_focus_area_History & Civics',
#  'secondary_focus_area_Music & The Arts',
#  'secondary_focus_subject_Health & Wellness',
#  'primary_focus_subject_Visual Arts',
#  'secondary_focus_subject_Performing Arts',
#  'secondary_focus_subject_Foreign Languages',
#  'primary_focus_area_History & Civics',
#  'grade_level_Grades 3-5',
#  'school_state_nan',
#  'secondary_focus_subject_Community Service',
#  'students_reached_norm',
#  'school_state_KY',
#  'school_state_MA',
#  'school_state_SD',
#  'school_charter',
#  'poverty_level_high poverty',
#  'primary_focus_subject_Early Development',
#  'primary_focus_subject_Music',
#  'resource_type_Technology',
#  'school_state_FL',
#  'secondary_focus_subject_Nutrition',
#  'resource_type_Trips',
#  'secondary_focus_area_Literacy & Language',
#  'secondary_focus_subject_Literacy',
#  'teacher_is_female',
#  'resource_type_Books',
#  'secondary_focus_subject_History & Geography',
#  'total_price_norm',
#  'school_state_GA',
#  'school_state_NH',
#  'school_state_LA',
#  'secondary_focus_subject_Extracurricular',
#  'school_state_OH',
#  'school_state_RI',
#  'school_state_PA',
#  'primary_focus_subject_History & Geography',
#  'primary_focus_area_nan',
#  'grade_level_Grades 9-12',
#  'primary_focus_subject_Gym & Fitness',
#  'school_metro_urban',
#  'primary_focus_subject_Environmental Science',
#  'school_state_WI',
#  'primary_focus_subject_Extracurricular',
#  'grade_level_nan',
#  'school_state_UT',
#  'in_big_city',
#  'primary_focus_subject_Economics',
#  'primary_focus_subject_Health & Wellness',
#  'school_metro_suburban',
#  'school_state_NC',
#  'primary_focus_subject_Health & Life Science',
#  'school_magnet',
#  'school_state_DE',
#  'primary_focus_area_Applied Learning',
#  'school_state_CA']

# %% [markdown]
# ### Create training and test sets: expanding-window temporal cross-validation

# %%
lag_time = datetime.timedelta(days=60)
proj = pipe.create_sliding_window_sets(proj, 'date_posted', features, 'not_funded', 26, lag_time)

intervals = list(proj.interval.unique())
k = len(intervals) - 1
x_train0 = proj[features].loc[proj.interval == intervals[1]]
y_train0 = proj['not_funded'].loc[proj.interval == intervals[1]]
x_test0 = proj[features].loc[proj.interval == intervals[2]]
y_test0 = proj['not_funded'].loc[proj.interval == intervals[2]]

# %%
def create_sliding_window_sets(df, date_col, feature_list, target, time_interval, lag_time):
    ''' Takes full dataframe, string name of date column, list of features, 
        string name of target variable, number of intervals, and any lag time.
        Returns dataframe with bins corresponding to interval membership
    '''

    df[date_col] = pd.to_datetime(df[date_col])

    breaks = pipe.convert_duration_to_interval(df, date_col, time_interval)
    df['interval'] = pd.cut(df[date_col], breaks, include_lowest=True)
    
#     we don't want to include any observations too close to train/test date,
#     if we haven't yet observed their outcome
    if lag_time:
        df['interval'] = np.where(df[date_col] + lag_time > df['interval'].apply(lambda x: x.right), np.nan, df.interval)



    return df

test = create_sliding_window_sets(proj, 'date_posted', features, 'not_funded', 26, lag_time)
list(pd.DataFrame(test.interval.unique()).dropna().sort_values(0)[0])
# Out:
# [Interval('2011-12-31 23:59:59.999999999', '2012-07-01', closed='right'),
#  Interval('2012-07-01', '2012-12-30', closed='right'),
#  Interval('2012-12-30', '2013-06-30', closed='right'),
#  Interval('2013-06-30', '2013-12-31', closed='right')]

# %%
pd.to_datetime('2012-11-20') in test.interval.unique()[2]
# Out:
# True

# %%
classifier = pipe.build_classifier('SVM', x_train0, y_train0, penalty = 'l2')
pipe.draw_precision_recall_curve(classifier, x_test0, y_test0)
# Out:
# /Users/cecilemurray/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 1       {'criterion': 'gini', 'max_depth': 3}
# 2       {'criterion': 'gini', 'max_depth': 3}
# 3       {'criterion': 'gini', 'max_depth': 3}
# 4       {'criterion': 'gini', 'max_depth': 3}
# 5       {'criterion': 'gini', 'max_depth': 3}
# 6       {'criterion': 'gini', 'max_depth': 3}
# 0       {'criterion': 'gini', 'max_depth': 5}
# 1       {'criterion': 'gini', 'max_depth': 5}
# 2       {'criterion': 'gini', 'max_depth': 5}
# 3       {'criterion': 'gini', 'max_depth': 5}
# 4       {'criterion': 'gini', 'max_depth': 5}
# 5       {'criterion': 'gini', 'max_depth': 5}
# 6       {'criterion': 'gini', 'max_depth': 5}
# 0      {'criterion': 'gini', 'max_depth': 10}
# 1      {'criterion': 'gini', 'max_depth': 10}
# 2      {'criterion': 'gini', 'max_depth': 10}
# 3      {'criterion': 'gini', 'max_depth': 10}
# 4      {'criterion': 'gini', 'max_depth': 10}
# 5      {'criterion': 'gini', 'max_depth': 10}
# 6      {'criterion': 'gini', 'max_depth': 10}
# 0      {'criterion': 'gini', 'max_depth': 15}
# 1      {'criterion': 'gini', 'max_depth': 15}
# ..                                        ...
# 5    {'criterion': 'entropy', 'max_depth': 1}
# 6    {'criterion': 'entropy', 'max_depth': 1}
# 0    {'criterion': 'entropy', 'max_depth': 3}
# 1    {'criterion': 'entropy', 'max_depth': 3}
# 2    {'criterion': 'entropy', 'max_depth': 3}
# 3    {'criterion': 'entropy', 'max_depth': 3}
# 4    {'criterion': 'entropy', 'max_depth': 3}
# 5    {'criterion': 'entropy', 'max_depth': 3}
# 6    {'criterion': 'entropy', 'max_depth': 3}
# 0    {'criterion': 'entropy', 'max_depth': 5}
# 1    {'criterion': 'entropy', 'max_depth': 5}
# 2    {'criterion': 'entropy', 'max_depth': 5}
# 3    {'criterion': 'entropy', 'max_depth': 5}
# 4    {'criterion': 'entropy', 'max_depth': 5}
# 5    {'criterion': 'entropy', 'max_depth': 5}
# 6    {'criterion': 'entropy', 'max_depth': 5}
# 0   {'criterion': 'entropy', 'max_depth': 10}
# 1   {'criterion': 'entropy', 'max_depth': 10}
# 2   {'criterion': 'entropy', 'max_depth': 10}
# 3   {'criterion': 'entropy', 'max_depth': 10}
# 4   {'criterion': 'entropy', 'max_depth': 10}
# 5   {'criterion': 'entropy', 'max_depth': 10}
# 6   {'criterion': 'entropy', 'max_depth': 10}
# 0   {'criterion': 'entropy', 'max_depth': 15}
# 1   {'criterion': 'entropy', 'max_depth': 15}
# 2   {'criterion': 'entropy', 'max_depth': 15}
# 3   {'criterion': 'entropy', 'max_depth': 15}
# 4   {'criterion': 'entropy', 'max_depth': 15}
# 5   {'criterion': 'entropy', 'max_depth': 15}
# 6   {'criterion': 'entropy', 'max_depth': 15}
#
# [70 rows x 7 columns]

# %%
# pipe.test_classifiers(x_train0, y_train0, x_test0, y_test0, classifier_dict = pipe.TEST_CLASSIFIERS, thresholds = [0.65, 0.75])

# %%
# pipe.get_feature_wt(classifier, features)

# %%
# classifier.feature_importances_.max()

# %%
pd.DataFrame(np.array(list(range(10))))[0].unique().shape
# Out:
# (10,)
